# %%
ls
# Out:
# sample_data/

# %%
            ######################### modify embedding #########################
            with open('save/input/embedding_kyu.pkl', 'rb') as fp:
                embedding_matrix_kudl = cPickle.load(fp)                    

            self.g_embeddings = tf.get_variable(name = "Word_embedding",
                             shape = [self.num_emb, self.emb_dim],
                             initializer=tf.constant_initializer(np.array(embedding_matrix_kudl)),
                             trainable = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-d60f44b7374b> in <module>()
# ----> 1 with open('save/input/embedding_kyu.pkl', 'rb') as fp:
#       2     embedding_matrix_kudl = cPickle.load(fp)
#       3
#       4 self.g_embeddings = tf.get_variable(name = "Word_embedding",
#       5                  shape = [self.num_emb, self.emb_dim],
#
# FileNotFoundError: [Errno 2] No such file or directory: 'save/input/embedding_kyu.pkl'

# %%
            ######################### modify embedding #########################
            with open('save/input/embedding_kyu.pkl', 'rb') as fp:
                embedding_matrix_kudl = cPickle.load(fp)                    

            self.g_embeddings = tf.get_variable(name = "Word_embedding",
                             shape = [self.num_emb, self.emb_dim],
                             initializer=tf.constant_initializer(np.array(embedding_matrix_kudl)),
                             trainable = False)
